# %%
# Load Dataset and libraries

# %%
! nvidia-smi -L
# Out:
# GPU 0: NVIDIA GeForce GTX 1080 (UUID: GPU-6e527b20-979e-9e78-a1b3-f506780ccc06)

# %%
import pandas as pd
import numpy as np
import string
from collections import Counter
from wordcloud import WordCloud
import matplotlib.pyplot as plt
from gensim.models import Word2Vec

# %%
df = pd.read_csv("test_data.csv")
df['news_site'] = df['publisher'].apply(lambda x: eval(x)['title'] if isinstance(x, str) else None)
df_clean = df[['news_site', 'title']]
df_clean.head(10)
# Out:
#                            news_site  \
# 0                  Spectrum News NY1
# 1                              Prism
# 2                 The Stanford Daily
# 3  The Independent Florida Alligator
# 4                         Mast Media
# 5                   WDSU New Orleans
# 6                              NYCLU
# 7                   Middletown Press
# 8                           ABC News
# 9         Oregon Public Broadcasting
#
#                                                title
# 0  How a student protest plan helped get a playgr...
# 1  Pro-Palestine student organizers face crackdow...
# 2  A parent's perspective on Family Weekend activ...
# 3  Students, staff and faculty protest DEI decisi...
# 4  Politics of Silence: Student Protest Stops Spe...
# 5  New Orleans professor Walter Isaacson accused ...
# 6  NYCLU and Palestine Legal Sue Columbia Univers...
# 7  Middletown High students protest unsatisfactor...
# 8  Students protest DEI firings at the University...
# 9  Students walk out, demand action on Gaza from ...

# %%
# Vectorize using Word2Vec

# %%
df_clean['processed_title'] = df_clean['title'].str.lower()
df_clean['processed_title'] = df_clean['processed_title'].str.translate(str.maketrans('', '', string.punctuation))
df_clean['processed_title'] = df_clean['processed_title'].str.split()

sentences = df_clean['processed_title'].tolist()
word2vec = Word2Vec(sentences, vector_size=100, window=5, min_count=1, workers=4)
# Out:
# /tmp/ipykernel_715/3013998924.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_clean['processed_title'] = df_clean['title'].str.lower()
# /tmp/ipykernel_715/3013998924.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_clean['processed_title'] = df_clean['processed_title'].str.translate(str.maketrans('', '', string.punctuation))
# /tmp/ipykernel_715/3013998924.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_clean['processed_title'] = df_clean['processed_title'].str.split()

# %%
vectors = []
for tokens in df_clean['processed_title']:
    vectors.append(np.mean([word2vec.wv[word] for word in tokens if word in word2vec.wv] or [np.zeros(word2vec.vector_size)], axis=0))

# %%
headline_vectors = pd.DataFrame(vectors)
headline_vectors.head(10)
# Out:
#          0         1         2         3         4         5         6   \
# 0 -0.003297  0.008889  0.003020  0.000592  0.005158 -0.008821  0.004331
# 1 -0.003834  0.007044  0.001060 -0.001804  0.005763 -0.003891  0.004634
# 2 -0.001721  0.008190  0.003233 -0.002627  0.001469 -0.008475  0.005421
# 3 -0.005969  0.010277  0.002707 -0.000336  0.006510 -0.010914  0.006891
# 4 -0.005595  0.013062  0.003333 -0.002183  0.005684 -0.011309  0.008792
# 5 -0.003489  0.006131  0.001153 -0.001077  0.003466 -0.007844  0.003433
# 6 -0.004428  0.006716  0.002113 -0.000430  0.007788 -0.012522  0.004945
# 7 -0.005569  0.012607  0.002785 -0.003313  0.003741 -0.009459  0.004469
# 8 -0.007472  0.012995  0.004043  0.001108  0.010647 -0.018001  0.009659
# 9 -0.002009  0.007911  0.002261 -0.002804  0.006073 -0.012954  0.005598
#
#          7         8         9   ...        90        91        92        93  \
# 0  0.020456 -0.007580 -0.006976  ...  0.006560  0.006826  0.002275 -0.000719
# 1  0.015255 -0.004034 -0.003325  ...  0.004185  0.004026  0.005444  0.001141
# 2  0.017890 -0.002929 -0.006869  ...  0.006146  0.005036  0.002877  0.003405
# 3  0.024676 -0.004985 -0.005685  ...  0.009159  0.003134  0.003104 -0.000641
# 4  0.025156 -0.010396 -0.008525  ...  0.009012  0.006628  0.002948 -0.000096
# 5  0.016898 -0.004492 -0.004366  ...  0.002454  0.002649  0.002828 -0.000741
# 6  0.021743 -0.008021 -0.008598  ...  0.009372  0.004956  0.002981  0.002656
# 7  0.019836 -0.006031 -0.010463  ...  0.005989  0.007002  0.002360  0.000554
# 8  0.035023 -0.009278 -0.011379  ...  0.011198  0.006425  0.008218  0.003448
# 9  0.020116 -0.005180 -0.006210  ...  0.006447  0.002723  0.004377  0.002825
#
#          94        95        96        97        98        99
# 0  0.014109  0.005287  0.003784 -0.006499  0.004584 -0.002223
# 1  0.012029  0.005760  0.005635 -0.004940  0.004087 -0.003969
# 2  0.011574  0.005484 -0.000279 -0.003452  0.004776  0.000399
# 3  0.019471  0.007999  0.003411 -0.010568  0.002561 -0.003064
# 4  0.019873  0.010604  0.005294 -0.010961  0.002980 -0.006133
# 5  0.012661  0.005125  0.004978 -0.006835  0.002631 -0.002343
# 6  0.017967  0.005784  0.001261 -0.007084  0.002342 -0.006467
# 7  0.017359  0.006083  0.006158 -0.011113  0.002819 -0.000771
# 8  0.027164  0.011894  0.005090 -0.013641  0.006293 -0.004472
# 9  0.014309  0.005599  0.002732 -0.006944  0.003361 -0.004155
#
# [10 rows x 100 columns]

# %%
#Cluster

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt

scaler = StandardScaler()
X_scaled = scaler.fit_transform(headline_vectors)

num_clusters = 5
km = KMeans(n_clusters=num_clusters, random_state=42)
km.fit(X_scaled)
df_clean['cluster'] = km.labels_

pca = PCA(n_components=2)
X_pca = pca.fit_transform(X_scaled)

plt.figure(figsize=(12, 8))
for cluster in range(num_clusters):
    plt.scatter(X_pca[df_clean['cluster'] == cluster, 0], X_pca[df_clean['cluster'] == cluster, 1], label=f'Cluster {cluster}')
plt.xlabel('PCA Component 1')
plt.ylabel('PCA Component 2')
plt.title('Headline Clusters')
plt.legend()
plt.show()
# Out:
# /tmp/ipykernel_715/3553328283.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_clean['cluster'] = km.labels_

# %%
for cluster in sorted(df_clean['cluster'].unique()):
    print(f"\nCluster {cluster} Sample Headlines:")
    sample_headlines = df_clean[df_clean['cluster'] == cluster]['title'].sample(5, random_state=42).tolist()
    for headline in sample_headlines:
        print(f"- {headline}")
# Out:
# Cluster 0 Sample Headlines:
# - Student demonstration in solidarity of suspended peers disbanded by administrators - Student Life
# - 20 arrested after students occupy administration building at Pomona College in support of Palestinians - San Bernardino County Sun
# - Berkeley professor attempts to grab mic from Palestinian student during protest - NBC News
# - 20 arrested after Pomona College students protest; demonstrators then move to Claremont police station - KABC-TV
# - Vancouver students walk out of class in protest of $35 million in budget cuts - KGW.com
#
# Cluster 1 Sample Headlines:
# - UT-Austin professors, students protest on campus: Live updates - Austin American-Statesman
# - Mexican police kill Ayotzinapa student hours after AMLO likened protest to “dirty war” - WSWS
# - President-designate Jonathan Alger welcomed in traditional AU fashion: Protest - The Eagle (American University)
# - Northampton High students walk out of school, camp in mayor's office over proposed cuts to theater department - GazetteNET
# - Rittenhouse’s visit to University of Memphis cut short by students, protestors - Action News 5
#
# Cluster 2 Sample Headlines:
# - Columbia University protests: Negotiations continue between school and student protesters after no arrests Saturday - WABC-TV
# - VIDEO: Student protesters arrested after Vanderbilt incident - WSMV 4
# - State responses to student protests fall along red vs. blue lines - The Hill
# - US college protests: Biden insists "order must prevail" - The Associated Press
# - 150 students take part in pro-Palestine, pro-Israel protests in Oklahoma Memorial Union - The Oklahoma Daily
#
# Cluster 3 Sample Headlines:
# - Jewish UC Berkeley student recalls fearing for her life when protesters disrupted event - CBS San Francisco
# - Pro-Palestine student organizers face crackdowns by universities, legal charges - Prism
# - Sensationalizing campus antisemitism isn't serving Jewish students like mine - JTA News - Jewish Telegraphic Agency
# - American University silent amid concerns over sweeping speech bans - Foundation for Individual Rights and Expression
# - UCF students successfully kick Lockheed Martin event off campus - Fight Back! Newspaper
#
# Cluster 4 Sample Headlines:
# - Harvard students prop up tents to protest war in Gaza and suspension of campus group - WBUR News
# - Students protest DEI firings at the University of Florida - ABC News
# - College protests: Police arrest pro-Palestinian student protesters at USC - The Associated Press
# - How Should Colleges Handle Student Protests? - The New York Times
# - OPINION: Understanding the power of student activism - Indiana Daily Student

# %%
# Will add another cluster by political leaning instead of word2vec

# %%
# NOTE: Aside from clustering, use semantic analysis and or recluster by political leaning of news outlets.
# Will add politcal leanings to test data to see how clustering will work out.

# %%
# Simulated Political Leaning Scores

# %%
values = [-1, -0.5, 0, 0.5, 1]
df_clean['Political Leaning'] = np.random.choice(values, size=len(df_clean))
# Out:
# /tmp/ipykernel_715/1362126679.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_clean['Political Leaning'] = np.random.choice(values, size=len(df_clean))

# %%
df_clean
# Out:
#                              news_site  \
# 0                    Spectrum News NY1
# 1                                Prism
# 2                   The Stanford Daily
# 3    The Independent Florida Alligator
# 4                           Mast Media
# ..                                 ...
# 495                                NPR
# 496                 Rutgers University
# 497                               WCAX
# 498                           NBC News
# 499                    The Guardian US
#
#                                                  title  \
# 0    How a student protest plan helped get a playgr...
# 1    Pro-Palestine student organizers face crackdow...
# 2    A parent's perspective on Family Weekend activ...
# 3    Students, staff and faculty protest DEI decisi...
# 4    Politics of Silence: Student Protest Stops Spe...
# ..                                                 ...
# 495  In the 1980s, he led student protests. Now, he...
# 496  Statement to Board of Governors on Student Pro...
# 497  Student protesters demand UVM, Middlebury Coll...
# 498  Once champions of free speech, colleges crack ...
# 499  Dozens arrested at Columbia University as New ...
#
#                                        processed_title  cluster  \
# 0    [how, a, student, protest, plan, helped, get, ...        1
# 1    [propalestine, student, organizers, face, crac...        3
# 2    [a, parents, perspective, on, family, weekend,...        3
# 3    [students, staff, and, faculty, protest, dei, ...        1
# 4    [politics, of, silence, student, protest, stop...        0
# ..                                                 ...      ...
# 495  [in, the, 1980s, he, led, student, protests, n...        2
# 496  [statement, to, board, of, governors, on, stud...        4
# 497  [student, protesters, demand, uvm, middlebury,...        1
# 498  [once, champions, of, free, speech, colleges, ...        2
# 499  [dozens, arrested, at, columbia, university, a...        4
#
#      Political Leaning
# 0                 -1.0
# 1                  1.0
# 2                  1.0
# 3                  0.5
# 4                  0.0
# ..                 ...
# 495                0.5
# 496                0.5
# 497                0.0
# 498                0.5
# 499                0.0
#
# [500 rows x 5 columns]

# %%
# Wordcloud with top 5 words removed (Markdown)

# %% [markdown]
# for cluster_num in range(num_clusters):
#     cluster_data = df_clean[df_clean['cluster'] == cluster_num]
#     text = ' '.join(cluster_data['title'].tolist())
#     words = text.split()
#     word_counts = Counter(words)
#     most_common_words = [word for word, _ in word_counts.most_common(5)]
#     filtered_words = [word for word in words if word not in most_common_words]
#     filtered_text = ' '.join(filtered_words)
#
#     wordcloud = WordCloud(width=800, height=400, background_color='white').generate(filtered_text)
#     plt.figure(figsize=(10, 5))
#     plt.imshow(wordcloud, interpolation='bilinear')
#     plt.title(f'Word Cloud for Cluster {cluster_num} (Top 5 Words Removed)')
#     plt.axis('off')
#     plt.show()

# %%
# Wordcloud with specific keywords targeted

# %%
keywords_to_remove = {'student', 'students','university', 'college', 
                      'school', 'education', 'campus', 'class', 
                      'course', 'degree', 'faculty', 'protest', 
                     'protesters', 'protester', 'new', 'news'}

for cluster_num in range(num_clusters):
    cluster_data = df_clean[df_clean['cluster'] == cluster_num]
    text = ' '.join(cluster_data['title'].tolist())
    words = text.split()
    filtered_words = [word for word in words if word.lower() not in keywords_to_remove]
    filtered_text = ' '.join(filtered_words)
    
    wordcloud = WordCloud(width=800, height=400, background_color='white').generate(filtered_text)
    plt.figure(figsize=(10, 5))
    plt.imshow(wordcloud, interpolation='bilinear')
    plt.title(f'Word Cloud for Cluster {cluster_num} (Specific Keywords Removed)')
    plt.axis('off')
    plt.show()

# %%
#Linreg

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, r2_score

# %%
X_lin = np.vstack(headline_vectors.values)
y_lin = df_clean['Political Leaning'].values

X_train, X_test, y_train, y_test = train_test_split(X_lin, y_lin, test_size=0.2, random_state=42)

reg_model = LinearRegression()
reg_model.fit(X_train, y_train)

y_pred = reg_model.predict(X_test)

mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

coefficients = pd.DataFrame(reg_model.coef_, index=range(100), columns=['Coefficient'])

mse, r2, coefficients.head()
# Out:
# (0.6814850243946627,
#  -0.4121115300345266,
#     Coefficient
#  0    -9.771244
#  1   -54.031693
#  2   -47.391956
#  3    12.270023
#  4   -33.622955)

# %%
#TF-IDF up next
